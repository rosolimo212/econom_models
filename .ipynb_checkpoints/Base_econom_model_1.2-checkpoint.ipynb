# %%
import random
import numpy as np
import pandas as pd

#настройки, с которыми лучше
pd.set_option('display.max_rows', 45000)
pd.set_option('display.max_columns', 50000)
pd.set_option('display.max_colwidth', 5000)

import sys
import smith as smith

import datetime

from pylab import rcParams
rcParams['figure.figsize'] = 14, 12

# %%
mode='read'
# mode='generate'

fact_file='data/fact_2020-01-03 22:55:26.724423.csv'
cit_file='data/cit_2020-01-03 22:55:26.753934.csv'

# число жителей
N=2000
# N=3

# число заводов
k=50
# k=3

# число раундов в модели
R=30
# R=2

# %%
# новый эксперимент
if mode=='generate':
    # генерация жителей
    cit_lst=[]
    for i in range(N):
        cit=smith.citizen(id=i)
        cit_lst.append(cit)

    # генерация заводов
    fact_lst=[]
    for i in range(k):
        fact=smith.factory(id=i)
        fact_lst.append(fact)

    # старт модели
    cit_df=pd.DataFrame()
    fact_df=pd.DataFrame()
    cit_df, fact_df=smith.model(cit_lst, fact_lst, R)

    # дополнительные поля для удобной работы
    lag=fact_df.sort_values(by='period').groupby(['id']).shift(1)
    fact_df['lag_price']=lag['price']
    fact_df['lag_qv']=lag['max_quality']
    fact_df['lag_pur']=lag['pur']
    fact_df['lag_capital']=lag['capital']

    fact_df['diff_price']=fact_df['price']-fact_df['lag_price']
    fact_df['diff_qv']=fact_df['max_quality']-fact_df['lag_qv']
    fact_df['diff_pur']=fact_df['pur']-fact_df['lag_pur']
    fact_df['diff_capital']=fact_df['capital']-fact_df['lag_capital']

    # запись результатов в файл
    fact_df.to_csv('data/fact_'+str(datetime.datetime.now())+'.csv', index=False)
    cit_df.to_csv('data/cit_'+str(datetime.datetime.now())+'.csv', index=False )
    
# читаем уже проведённый эксперимент
else:
    if mode=='read':  
        fact_df=pd.read_csv(fact_file)
        cit_df=pd.read_csv(cit_file)

# %%
len(cit_df)
# Out:
# 60000

# %%
cit_df[0:3]
# Out:
#    id  quality  price  citizen_id  money  period
# 0  20     26.0   18.0           0  20.63       0
# 1   4     15.0    7.0           1  12.37       0
# 2  20     26.0   18.0           2  25.09       0

# %%
fact_df[fact_df['period']==29].sort_values(by='capital', ascending=False)
# Out:
#       id  max_quality    cost   capital   pur   price  period  lag_price  \
# 1461  11         57.0   23.01  34736.07  1173   24.01      29      50.86
# 1470  20         17.0   15.56   9944.76     0   16.56      29      72.28
# 1450   0         28.0    1.16   2950.04   823    2.16      29      43.02
# 1451   1         27.0    5.65   1792.20     0    6.65      29       0.00
# 1454   4          7.0   13.47   1376.37     0   14.47      29      88.56
# 1477  27          7.0    7.11     47.14     0    8.11      29       2.16
# 1472  22          8.0   24.83     41.99     0   25.83      29      51.27
# 1467  17          6.0    6.36     36.66     0    7.36      29      61.72
# 1473  23         32.0   64.44     33.10     0   65.44      29      36.74
# 1471  21         11.0   40.74     32.32     0   41.74      29      74.82
# 1481  31         25.0   15.74     31.64     0   16.74      29       6.41
# 1484  34         21.0   42.02     29.13     0   43.02      29      66.69
# ...

# %%
pur=fact_df[fact_df['pur']>0].sort_values(by='pur')

# %%
pur_fact=fact_df[fact_df['pur']>0]['id'].drop_duplicates()
fact_df['pur_group']=np.where(fact_df['id'].isin(pur_fact)==True,1,0)

# %%
fact_df[(fact_df['pur_group']==0)].pivot_table(index='period', columns='id', values='capital').plot(legend=False, 
                                 figsize=(12,9), 
                                 title='Capitalisation dynamics of factories withought purchases'
                                                                          )

# %%
fact_df[(fact_df['pur_group']==1)].pivot_table(index='period', columns='id', values='capital').plot(legend=True, 
                                 figsize=(12,9), 
                                 title='Capitalisation dynamics of factories with purchases'
                                                                          )

# %%
pur.pivot_table(index='period', columns='id', values='pur').fillna(0).plot(legend=False, 
                                                                           figsize=(12,9), kind='bar',
                                                                           stacked=True, colormap='PuBu',
                                                                           edgecolor='blue',
                                                                           title='Number of purchases dynamics'
                                                                          )

# %%
fact_df[fact_df['id']==11][['period', 'price', 'max_quality', 'pur']]
# Out:
#       period  price  max_quality   pur
# 11         0  37.00         28.0   151
# 61         1  42.60         26.0     0
# 111        2  37.00         28.0   572
# 161        3  36.63         24.0     0
# 211        4  37.00         28.0     0
# 261        5  30.18         29.0     0
# 311        6  31.50         33.0   785
# 361        7  27.02         34.0   999
# 411        8  23.24         42.0  1221
# 461        9  21.05         43.0  1333
# 511       10  30.69         38.0     0
# 561       11  21.05         43.0     0
# 611       12  19.24         47.0  1432
# 661       13  11.11         49.0  1793
# 711       14   9.26         44.0  1856
# 761       15  14.26         45.0  1672
# 811       16  15.19         44.0  1625
# 861       17  14.30         42.0  1669
# 911       18  11.57         45.0  1774
# 961       19  15.31         45.0  1622
# 1011      20   9.29         47.0  1863
# 1061      21   2.26         49.0  1995
# 1111      22   5.53         49.0  1958
# ...

# %%
1995/2000
# Out:
# 0.9975

# %%
fact_df[fact_df['id']==11][['period', 'price', 'max_quality']].set_index('period').plot(title='id=11 dynamics')

# %%
np.median(cit_df[cit_df['period']==0]['money'])
# Out:
# 27.545

# %%
fact_df[fact_df['id']==0][['period', 'price', 'max_quality', 'pur']]
# Out:
#       period  price  max_quality  pur
# 0          0  15.00         22.0  141
# 50         1   5.45         16.0    0
# 100        2  15.00         22.0  419
# 150        3  13.95         20.0    0
# 200        4  15.00         22.0    0
# 250        5  18.15         27.0    0
# 300        6  14.01         27.0  860
# 350        7  17.05         29.0    0
# 400        8  14.01         27.0  286
# 450        9  14.17         31.0    0
# 500       10  14.01         27.0   57
# 550       11  18.08         24.0    0
# 600       12  14.01         27.0  204
# 650       13  10.39         29.0   18
# 700       14   9.24         27.0    1
# 750       15   8.59         23.0   74
# 800       16   6.18         25.0    0
# 850       17   8.59         23.0    0
# 900       18   6.54         25.0    0
# 950       19   2.31         30.0  195
# 1000      20   2.26         27.0    0
# 1050      21   2.31         30.0    0
# 1100      22   2.31         32.0    0
# 1150      23   2.31         32.0    0
# ...

# %%
fact_df[fact_df['id']==0][['period', 'price', 'max_quality']].set_index('period').plot(title='id=0 dynamics')

# %%
fact_df[fact_df['id']==20][['period', 'price', 'max_quality', 'pur', 'capital']]
# Out:
#       period  price  max_quality   pur   capital
# 20         0  18.00         26.0   905   1933.39
# 70         1  22.48         27.0   991   2799.56
# 120        2  24.52         27.0   564   3275.73
# 170        3  17.83         28.0   876   4028.75
# 220        4  14.25         27.0   978   4959.69
# 270        5  14.39         31.0  1658   6525.50
# 320        6  14.67         26.0     0   6349.77
# 370        7  14.39         31.0   638   6987.77
# 420        8  19.92         32.0   177   7056.68
# 470        9  13.01         39.0   390   7301.18
# 520       10  15.11         39.0  1618   8886.39
# 570       11  16.17         44.0  1572  10303.69
# 620       12  18.31         39.0    48  10285.72
# 670       13  10.83         40.0    12  10207.23
# 720       14  14.68         42.0     0  10153.44
# 770       15  10.83         40.0   133  10286.44
# 820       16   1.55         41.0   373  10555.55
# 870       17   2.87         37.0   324  10766.28
# ...

# %%
fact_df[fact_df['id']==20][['period', 'price', 'max_quality']].set_index('period').plot(title='id=20 dynamics')

# %%
f0=fact_df[fact_df['period']==0].sort_values(by='price')
f0['pur_group']=np.where(f0['pur']>0,1, 0)
f0g1=f0[f0['pur']>0]
f0g2=f0[f0['pur']==0]

ax = f0g1.plot.scatter(x='price', y='max_quality', color='DarkBlue', label='Had purchases', s=50)
f0g2.plot.scatter(x='price', y='max_quality', color='Red', label='No purchases', s=50,
                  ax=ax, figsize=(12,9), title='Round 0')

# %%
f0=fact_df[fact_df['period']==29].sort_values(by='price')
f0['pur_group']=np.where(f0['pur']>0,1, 0)
f0g1=f0[f0['pur']>0]
f0g2=f0[f0['pur']==0]

ax = f0g1.plot.scatter(x='price', y='max_quality', color='DarkBlue', label='Had purchases', s=50)
f0g2.plot.scatter(x='price', y='max_quality', color='Red', label='No purchases', s=50,
                  ax=ax, figsize=(12,9), title='Round 29')

# %%
pur[0:3]
# Out:
#      id  max_quality   cost  capital  pur  price  period  lag_price  lag_qv  \
# 700   0         27.0   8.24  2306.62    1   9.24      14      51.27    15.0
# 76   26         31.0  84.55  1162.23    1  85.55       1      14.00    21.0
# 804   4         14.0   0.40  2598.69    1   1.40      16      68.26    17.0
#
#      lag_pur  lag_capital  diff_price  diff_qv  diff_pur  diff_capital
# 700      0.0         8.47      -42.03     12.0       1.0       2298.15
# 76      54.0      1587.39       71.55     10.0     -53.0       -425.16
# 804      0.0        38.13      -66.86     -3.0       1.0       2560.56

# %%
pur.plot.scatter(x='period', y='price', figsize=(14,12))

# %%
pur.plot.scatter(x='period', y='price', s=10+pur['pur']/40, figsize=(14,12))

# %%
pur.plot.scatter(x='period', y='max_quality', figsize=(14,12))

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
fig, ax = plt.subplots()

pur['pur_group']=np.where(pur['pur']>100, 70, 
                          np.where(pur['pur']>10,20,10))

colormap = cm.Dark2
colorlist = [colors.rgb2hex(colormap(i)) for i in np.linspace(0, 0.9, len(pur['id']))]

for i,c in enumerate(colorlist):
    x = pur['period'].values[i]
    y = pur['price'].values[i]
    l = pur['id'].values[i]
    s = pur['pur_group'].values[i]

    ax.scatter(x, y, label=l, s=s, linewidth=0.1, c=c)

# ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
fig, ax = plt.subplots()

pur['pur_group']=np.where(pur['pur']>100, 70, 
                          np.where(pur['pur']>10,20,10))

colormap = cm.Dark2
colorlist = [colors.rgb2hex(colormap(i)) for i in np.linspace(0, 0.9, len(pur['id']))]

for i,c in enumerate(colorlist):
    x = pur['period'].values[i]
    y = pur['max_quality'].values[i]
    l = pur['id'].values[i]
    s = pur['pur_group'].values[i]

    ax.scatter(x, y, label=l, s=s, linewidth=0.1, c=c)

# ax.legend()

plt.show()

# %%
from pylab import *
from numpy import outer

maps=[m for m in cm.datad if not m.endswith("_r")]
maps.sort()

# %%
maps
# Out:
# ['Accent',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'Dark2',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Set1',
#  'Set2',
#  'Set3',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'tab10',
#  'tab20',
#  'tab20b',
#  'tab20c',
#  'terrain',
#  'winter']

# %%
fact_df['diff_capital'].describe()
# Out:
# count     1450.000000
# mean        -2.190338
# std       4006.609631
# min     -33703.290000
# 25%       -146.687500
# 50%         -3.330000
# 75%         43.400000
# max      34731.760000
# Name: diff_capital, dtype: float64

# %%
fact_df[fact_df['diff_capital']<-33000]
# Out:
#    id  max_quality   cost  capital  pur  price  period  lag_price  lag_qv  \
# 0  38          6.0  55.77    13.23    0  56.77      29      13.47    54.0
#
#    lag_pur  lag_capital  diff_price  diff_qv  diff_pur  diff_capital
# 0   1706.0     33716.52        43.3    -48.0   -1706.0     -33703.29

# %%
fact_df[fact_df['id']==38]
# Out:
#    id  max_quality   cost  capital  pur  price  period  lag_price  lag_qv  \
# 0  38         25.0  76.00  1324.60    0  77.00       0        NaN     NaN
# 0  38         26.0  71.06  1264.09    0  72.06       1      25.00    16.0
# 0  38         20.0  68.40  1216.27    0  69.40       2      81.97     9.0
# 0  38         19.0  69.71  1089.42    0  70.71       3      22.46    22.0
# 0  38         16.0  60.71  1004.06    0  61.71       4      79.51     4.0
# 0  38         19.0  64.67   938.53    0  65.67       5      34.48    31.0
# 0  38         19.0  61.33   813.01    0  62.33       6      86.51    14.0
# 0  38         21.0  59.05   687.45    0  60.05       7      14.01    27.0
# 0  38         24.0  59.84   625.83    0  60.84       8      75.10     8.0
# 0  38         20.0  53.87   478.76    0  54.87       9      94.13     5.0
# 0  38         18.0  48.46   338.27    0  49.46      10      75.10     8.0
# 0  38         15.0  56.74   220.64    0  57.74      11      79.52    14.0
# ...

# %%
fact_df[fact_df['id']==44]
# Out:
#       Unnamed: 0  id  max_quality   cost   capital   pur  price  period  \
# 44             0  44         28.0   8.00   3192.06  1724   9.00       0
# 94             0  44         32.0   4.77   4899.79  1869   5.77       1
# 144            0  44         30.0  18.33   6075.70  1242  19.33       2
# 194            0  44         27.0  16.88   7299.33  1303  17.88       3
# 244            0  44         25.0  17.20   7284.72     0  18.20       4
# 294            0  44         27.0  16.88   7284.72     0  17.88       5
# 344            0  44         26.0  21.69   7688.24   492  22.69       6
# 394            0  44         26.0  19.32   7556.10     0  20.32       7
# 444            0  44         26.0  21.69   7556.10     0  22.69       8
# 494            0  44         23.0  26.40   7437.16     0  27.40       9
# 544            0  44         25.0  17.93   7491.10   166  18.93      10
# 594            0  44         24.0  17.70   7797.56   440  18.70      11
# ...

# %%
fact_df[['diff_price','diff_qv', 'diff_pur']]
# Out:
#       diff_price  diff_qv  diff_pur
# 0            NaN      NaN       NaN
# 1            NaN      NaN       NaN
# 2            NaN      NaN       NaN
# 3            NaN      NaN       NaN
# 4            NaN      NaN       NaN
# 5            NaN      NaN       NaN
# 6            NaN      NaN       NaN
# 7            NaN      NaN       NaN
# 8            NaN      NaN       NaN
# 9            NaN      NaN       NaN
# 10           NaN      NaN       NaN
# 11           NaN      NaN       NaN
# 12           NaN      NaN       NaN
# 13           NaN      NaN       NaN
# 14           NaN      NaN       NaN
# 15           NaN      NaN       NaN
# 16           NaN      NaN       NaN
# 17           NaN      NaN       NaN
# 18           NaN      NaN       NaN
# 19           NaN      NaN       NaN
# 20           NaN      NaN       NaN
# 21           NaN      NaN       NaN
# 22           NaN      NaN       NaN
# 23           NaN      NaN       NaN
# 24           NaN      NaN       NaN
# ...

# %%
cit_df.sample(4)
# Out:
#        Unnamed: 0  id  quality  price  citizen_id  money  period
# 19043           0  38     40.0  30.95        1043  93.62       9
# 15980           0  40     29.0   8.22        1980  27.75       7
# 20995           0  22     17.0   4.64         995  17.21      10
# 49751           0  38     35.0  16.93        1751  44.84      24

# %%
fact_df.sample(4)
# Out:
#      Unnamed: 0  id  max_quality   cost  capital  pur  price  period  id_group
# 838           0  38         43.0  32.57  6987.34  668  33.57      16         3
# 695           0  45          1.0  59.20    13.38    0  60.20      13         4
# 520           0  20          2.0  90.17    60.19    0  91.17      10         2
# 285           0  35         34.0  57.62   801.62  147  58.62       5         3

# %%
m0[0:20]
# Out:
#     Unnamed: 0  id  quality    price  citizen_id  money  period  money_group
# 0            0  44     28.0      9.0           0  29.52       0         30.0
# 1            0  44     28.0      9.0           1  33.00       0         35.0
# 2            0  44     28.0      9.0           2  15.88       0         15.0
# 3            0  36     30.0     58.0           3  72.10       0         70.0
# 4            0  44     28.0      9.0           4  21.97       0         20.0
# 5            0  44     28.0      9.0           5  29.20       0         30.0
# 6            0  44     28.0      9.0           6  28.00       0         30.0
# 7            0  44     28.0      9.0           7  55.04       0         55.0
# 8            0  44     28.0      9.0           8  47.68       0         50.0
# 9            0  44     28.0      9.0           9  23.49       0         25.0
# 10           0  44     28.0      9.0          10  35.49       0         35.0
# ...

# %%
sm_parameter=5
f0=fact_df[fact_df['period']==0].sort_values(by='price')
f0['money_group']=sm_parameter*np.round((f0['price']/sm_parameter),0)
f0['pur_group']=np.where(f0['pur']>0,1, 0)
f0g=f0.groupby(['money_group', 'max_quality']).agg({'id': lambda x: x.nunique()}).reset_index()

m0=cit_df[cit_df['period']==0]
m0['money_group']=sm_parameter*np.round((m0['money']/sm_parameter),0)
m0g=m0.groupby('money_group').agg({'citizen_id': lambda x: x.nunique()}).reset_index()
# Out:
# /home/roman/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
f0[0:3]
# Out:
#     Unnamed: 0  id  max_quality  cost  capital  pur  price  period  id_group  \
# 23           0  23         12.0   5.0  1001.41   20    6.0       0         2
# 15           0  15         16.0   6.0   840.18   29    7.0       0         1
# 40           0  40         27.0   7.0   598.96   33    8.0       0         4
#
#     money_group  pur_group
# 23          5.0          1
# 15          5.0          1
# 40         10.0          1

# %%
f0=fact_df[fact_df['period']==0].sort_values(by='price')
f0['pur_group']=np.where(f0['pur']>0,1, 0)
f0g1=f0[f0['pur']>0]
f0g2=f0[f0['pur']==0]

ax = f0g1.plot.scatter(x='price', y='max_quality', color='DarkBlue', label='Had purchases', s=50)
ax2=m0g.plot()
f0g2.plot.scatter(x='price', y='max_quality', color='Red', label='No purchases', s=50,
                  ax=ax, figsize=(12,9))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6e7257810658> in <module>
#       5
#       6 ax = f0g1.plot.scatter(x='price', y='max_quality', color='DarkBlue', label='Had purchases', s=50)
# ----> 7 ax2=m0g.plot()
#       8 f0g2.plot.scatter(x='price', y='max_quality', color='Red', label='No purchases', s=50,
#       9                   ax=ax, figsize=(12,9))
#
# NameError: name 'm0g' is not defined

# %%
f0
# Out:
#     Unnamed: 0  id  max_quality  cost  capital   pur  price  period  id_group  \
# 23           0  23         12.0   5.0  1001.41    20    6.0       0         2
# 15           0  15         16.0   6.0   840.18    29    7.0       0         1
# 40           0  40         27.0   7.0   598.96    33    8.0       0         4
# 26           0  26         14.0   7.0   100.20     0    8.0       0         2
# 22           0  22         20.0   8.0  1075.69     0    9.0       0         2
# 44           0  44         28.0   8.0  3192.06  1724    9.0       0         4
# 42           0  42          6.0  12.0  1503.81     0   13.0       0         4
# 1            0   1          4.0  14.0  1140.41     0   15.0       0         0
# 46           0  46          3.0  15.0   669.14     0   16.0       0         4
# 48           0  48         24.0  16.0  1885.49     0   17.0       0         4
# 34           0  34         16.0  25.0  1528.00     0   26.0       0         3
# ...

# %%
m0g=m0.groupby('money').agg({'citizen_id': lambda x: x.nunique()})#.reset_index()
m0g['citizen_id']=m0g['citizen_id']*4

# %%
m0g[0:3]
# Out:
#        citizen_id
# money
# 0.65            1
# 1.81            1
# 1.99            1
# 2.22            1
# 2.73            1

# %%
cit_df[cit_df['period']==0][['money']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4457c9c7f0>]],
#       dtype=object)

# %%
fact_df[fact_df['period']==0][['capital']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4456a06da0>]],
#       dtype=object)

# %%
fact_df[fact_df['period']==0][['max_quality']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4456943cf8>]],
#       dtype=object)

# %%
fact_df[fact_df['period']==0][['price']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f44568b9e48>]],
#       dtype=object)

# %%
fact_df[0:3]
# Out:
#    Unnamed: 0  id  max_quality  cost  capital  pur  price  period  id_group
# 0           0   0         26.0  79.0   821.02    0   80.0       0         0
# 1           0   1          4.0  14.0  1140.41    0   15.0       0         0
# 2           0   2          7.0  30.0   809.67    0   31.0       0         0

# %%
fact_df['id_group']=fact_df['id']//10

# %%
for idg in range(5):
    w=fact_df[fact_df['id_group']==idg]
    pur_evolution=w.pivot_table(index='period', columns='id', values='pur').fillna(0)
    price_evolution=w.pivot_table(index='period', columns='id', values='price').fillna(0)
    quality_evolution=w.pivot_table(index='period', columns='id', values='max_quality').fillna(0)
    capital_evolution=w.pivot_table(index='period', columns='id', values='capital').fillna(0)
    
    pur_evolution.plot()
    capital_evolution.plot()

# %%
w=fact_df[fact_df['pur']>0]
pur_evolution=w.pivot_table(index='period', columns='id', values='pur').fillna(0)
price_evolution=w.pivot_table(index='period', columns='id', values='price').fillna(0)
quality_evolution=w.pivot_table(index='period', columns='id', values='max_quality').fillna(0)
capital_evolution=w.pivot_table(index='period', columns='id', values='capital').fillna(0)

# %%
pur_evolution.plot(figsize=(12,9), title='Purchases')

# %%
capital_evolution.plot(figsize=(12,9), title='Capitalisation')

# %%
quality_evolution.plot(figsize=(12,9), title='Quality')

# %%
price_evolution.plot(figsize=(12,9), title='Price')

# %%
w.groupby('period').mean()[['price']].plot()

# %%
w.groupby('period').mean()[['max_quality']].plot()

# %%
w.groupby('period').mean()[['capital']].plot()

# %%
fact_df[fact_df['id']==15].set_index('period')[['max_quality', 'price']].plot()

# %%
fact_df[fact_df['id']==15].set_index('period')[['pur']].plot()

# %%
cit_df[0:3]
# Out:
#    Unnamed: 0  id  quality  price  citizen_id  money  period
# 0           0  44     28.0    9.0           0  29.52       0
# 1           0  44     28.0    9.0           1  33.00       0
# 2           0  44     28.0    9.0           2  15.88       0

# %%
pev=cit_df.groupby(['period', 'id', 'price', 'quality']).agg({'citizen_id': lambda x: x.nunique()}).reset_index()

# %%
pev.sort_values(by=['period', 'price'])
# Out:
#      period  id     price  quality  citizen_id
# 0         0  -1 -10000.00   -100.0          44
# 2         0  23      6.00     12.0          20
# 1         0  15      7.00     16.0          29
# 4         0  40      8.00     27.0          33
# 5         0  44      9.00     28.0        1724
# 3         0  36     58.00     30.0         150
# 6         1  -1 -10000.00   -100.0          26
# 7         1  15      4.84     17.0          17
# 9         1  44      5.77     32.0        1869
# 8         1  36     66.12     36.0          88
# 10        2  -1 -10000.00   -100.0          25
# 11        2  22      4.83     23.0          68
# 14        2  40      8.00     27.0         517
# 15        2  44     19.33     30.0        1242
# 12        2  35     58.27     32.0          72
# 13        2  36     67.78     35.0          76
# 16        3  -1 -10000.00   -100.0          12
# 18        3  26      4.11     16.0          14
# 17        3  15      4.84     17.0         147
# ...

# %%
fev=fact_df.groupby(['period', 'price', 'max_quality']).agg({'pur': np.sum}).reset_index()

# %%
fev.sort_values(by=['period', 'price'])
# Out:
#       period   price  max_quality   pur
# 0          0    6.00         12.0    20
# 1          0    7.00         16.0    29
# 2          0    8.00         14.0     0
# 3          0    8.00         27.0    33
# 4          0    9.00         20.0     0
# 5          0    9.00         28.0  1724
# 6          0   13.00          6.0     0
# 7          0   15.00          4.0     0
# 8          0   16.00          3.0     0
# 9          0   17.00         24.0     0
# 10         0   26.00         16.0     0
# 11         0   31.00          7.0     0
# 12         0   33.00         22.0     0
# 13         0   35.00          4.0     0
# 14         0   37.00         27.0     0
# 15         0   40.00          2.0     0
# 16         0   42.00          5.0     0
# 17         0   42.00         23.0     0
# 18         0   45.00          2.0     0
# 19         0   47.00         20.0     0
# 20         0   56.00         26.0     0
# 21         0   58.00         30.0   150
# ...
